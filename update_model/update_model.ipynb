# %%
import pandas as pd
import numpy as np


df=pd.read_csv('/home/madhu/recommendation-systems/data/user_ratings.csv')

df.head()
# Out:
#    Unnamed: 0   user                                               name  \
# 0           0  user0  HimQuen Girl's Trendy Wedges Sandal For Women/...
# 1           1  user0  BATA womens Deva Sandal Black Heeled Sandal - ...
# 2           2  user0                   Skechers Womens Skybound Sneaker
# 3           3  user0                         AZORES Women's Black Flats
# 4           4  user0         Skechers Womens City Pro - Glow on Sneaker
#
#    rating  main_category     sub_category
# 0       4  women's shoes            Shoes
# 1       4  women's shoes            Shoes
# 2       4  women's shoes            Shoes
# 3       5  women's shoes  Fashion Sandals
# 4       5  women's shoes            Shoes

# %%
new_df1=df.head(10000)
ratings_matrix = new_df1.pivot_table(values='rating', index='user', columns='name', fill_value=0)
ratings_matrix.head()
# Out:
# name    "INTERN SOPRANO 21" UKULELE WITH BAG (BLACK)  \
# user
# user0                                            0.0
# user1                                            0.0
# user10                                           0.0
# user11                                           0.0
# user12                                           0.0
#
# name    "TGC" Kaee Colour Dotted Matt Metal Bangle / Dark Green Color Chudi Set for Women and Girls (Pack of 24 Bangles)  \
# user
# user0                                                 0.0
# user1                                                 0.0
# user10                                                0.0
# user11                                                0.0
# user12                                                0.0
#
# name    (Renewed) Boya BYM1 Omnidirectional Lavalier Condenser Microphone with 20ft Audio Cable (Black)  \
# user
# user0                                                 0.0
# user1                                                 0.0
# user10                                                0.0
# user11                                                0.0
# user12                                                0.0
#
# name    (Renewed) Infinity (JBL) Fuze 100 4.5 Watt Wireless Bluetooth Portable Speaker (Passion Red)  \
# user
# user0                                                 0.0
# user1                                                 0.0
# user10                                                0.0
# user11                                                0.0
# user12                                                0.0
#
# name    (Renewed) Infinity Glide N100 Bluetooth Wireless In Ear Earphones with Mic (Blue)  \
# user
# user0                                                 0.0
# user1                                                 0.0
# user10                                                0.0
# user11                                                0.0
# user12                                                0.0
#
# name    (Renewed) JBL Tune 215BT Wireless Bluetooth In Ear Headphone with Mic (Blue)  \
# user
# user0                                                 0.0
# user1                                                 0.0
# user10                                                0.0
# user11                                                0.0
# user12                                                0.0
#
# name    (Renewed) Jbl C115Tws Bluetooth Truly Wireless In Ear Earbuds With Mic Black  \
# user
# user0                                                 0.0
# user1                                                 0.0
# user10                                                0.0
# user11                                                0.0
# user12                                                0.0
#
# name    (Renewed) Sony WI-C100 Wireless Headphones with 25 Hrs Battery, Quick Charge, DSEE-Upscale, Splash Proof (IPX4), 360RA, Cl...  \
# user
# user0                                                 0.0
# user1                                                 0.0
# user10                                                0.0
# user11                                                0.0
# user12                                                0.0
#
# name    (Renewed) Sony Wf-1000Xm4 Industry Leading Active Noise Cancellation 5.2 Bluetooth Tws In Ear Earbuds With Mic, 32Hr Batte...  \
# user
# user0                                                 0.0
# user1                                                 0.0
# user10                                                0.0
# user11                                                0.0
# user12                                                0.0
#
# name    (Renewed) boAt Airdopes 381 Bluetooth Truly Wireless In Ear Earbuds With Mic (Active Black)  \
# user
# user0                                                 0.0
# user1                                                 0.0
# user10                                                0.0
# user11                                                0.0
# user12                                                0.0
#
# name    ...  \
# user    ...
# user0   ...
# user1   ...
# user10  ...
# user11  ...
# user12  ...
#
# name    truke BTG Alpha True Gaming in Ear Earbuds with 40ms Low Latency Gaming Mode, 7 RGB LEDs, Instant Pairing, AAC Codec, Upto...  \
# user
# user0                                                 0.0
# user1                                                 0.0
# user10                                                0.0
# user11                                                0.0
# user12                                                0.0
#
# name    truke BTG Beta True Wireless in Ear Earbuds with 13mm Big Speaker Drivers, 38H Playtime, Fast Charging, True Gaming Mode, ...  \
# user
# user0                                                 0.0
# user1                                                 0.0
# user10                                                0.0
# user11                                                0.0
# user12                                                1.0
#
# name    usha heavy weight iron heavy weigt 1.75 kg - white  \
# user
# user0                                                 0.0
# user1                                                 0.0
# user10                                                0.0
# user11                                                0.0
# user12                                                0.0
#
# name    voltonix Table fan Powerful Rechargeable Table Fan with LED Light, Table Fan for Home, Table Fans, Table Fan for Office De...  \
# user
# user0                                                 0.0
# user1                                                 0.0
# user10                                                0.0
# user11                                                0.0
# user12                                                0.0
#
# name    wear your mind Grey Vest for Men MSV261  \
# user
# user0                                       0.0
# user1                                       0.0
# user10                                      0.0
# user11                                      0.0
# user12                                      0.0
#
# name    wipro Garnet 3W 2700K E27 Cap LED Bulb (Warm White/Yellow) - Pack of 4.  \
# user
# user0                                                 0.0
# user1                                                 0.0
# user10                                                0.0
# user11                                                0.0
# user12                                                0.0
#
# name    worldmacs 12'' Inches 2 Sided Drum Practice Pad + Bag + Drumsticks  \
# user
# user0                                                 0.0
# user1                                                 0.0
# user10                                                0.0
# user11                                                0.0
# user12                                                0.0
#
# name    xcluma 24V Color Changing Ultrasonic Mist Maker Fogger for Water Fountain Pond Atomizer Incubators Air Humidifier 12 LED W...  \
# user
# user0                                                 0.0
# user1                                                 0.0
# user10                                                0.0
# user11                                                0.0
# user12                                                0.0
#
# name    zhi yun Smooth Q3 Combo, Handheld 3-Axis Smartphone Gimbal Stabilizer with Grip Tripod LED Fill Light Protective Case Fold...  \
# user
# user0                                                 0.0
# user1                                                 0.0
# user10                                                0.0
# user11                                                0.0
# user12                                                0.0
#
# name    ÖUI Signature Edition Belgian Waffle Breakfast Mix I Eggless Waffle Mix | 360g
# user
# user0                                                 0.0
# user1                                                 0.0
# user10                                                0.0
# user11                                                0.0
# user12                                                0.0
#
# [5 rows x 7029 columns]

# %%
ratings_matrix.shape
# Out:
# (91, 7029)

# %%
X = ratings_matrix.T
X.head()
# Out:
# user                                                user0  user1  user10  \
# name
# "INTERN SOPRANO 21" UKULELE WITH BAG (BLACK)          0.0    0.0     0.0
# "TGC" Kaee Colour Dotted Matt Metal Bangle / Da...    0.0    0.0     0.0
# (Renewed) Boya BYM1 Omnidirectional Lavalier Co...    0.0    0.0     0.0
# (Renewed) Infinity (JBL) Fuze 100 4.5 Watt Wire...    0.0    0.0     0.0
# (Renewed) Infinity Glide N100 Bluetooth Wireles...    0.0    0.0     0.0
#
# user                                                user11  user12  user13  \
# name
# "INTERN SOPRANO 21" UKULELE WITH BAG (BLACK)           0.0     0.0     0.0
# "TGC" Kaee Colour Dotted Matt Metal Bangle / Da...     0.0     0.0     0.0
# (Renewed) Boya BYM1 Omnidirectional Lavalier Co...     0.0     0.0     0.0
# (Renewed) Infinity (JBL) Fuze 100 4.5 Watt Wire...     0.0     0.0     0.0
# (Renewed) Infinity Glide N100 Bluetooth Wireles...     0.0     0.0     0.0
#
# user                                                user14  user15  user16  \
# name
# "INTERN SOPRANO 21" UKULELE WITH BAG (BLACK)           0.0     0.0     0.0
# "TGC" Kaee Colour Dotted Matt Metal Bangle / Da...     0.0     0.0     0.0
# (Renewed) Boya BYM1 Omnidirectional Lavalier Co...     0.0     0.0     0.0
# (Renewed) Infinity (JBL) Fuze 100 4.5 Watt Wire...     0.0     0.0     0.0
# (Renewed) Infinity Glide N100 Bluetooth Wireles...     0.0     0.0     0.0
#
# user                                                user17  ...  user82  \
# name                                                        ...
# "INTERN SOPRANO 21" UKULELE WITH BAG (BLACK)           0.0  ...     0.0
# "TGC" Kaee Colour Dotted Matt Metal Bangle / Da...     0.0  ...     0.0
# (Renewed) Boya BYM1 Omnidirectional Lavalier Co...     0.0  ...     0.0
# (Renewed) Infinity (JBL) Fuze 100 4.5 Watt Wire...     0.0  ...     0.0
# (Renewed) Infinity Glide N100 Bluetooth Wireles...     0.0  ...     0.0
#
# user                                                user83  user84  user85  \
# name
# "INTERN SOPRANO 21" UKULELE WITH BAG (BLACK)           0.0     0.0     0.0
# "TGC" Kaee Colour Dotted Matt Metal Bangle / Da...     0.0     0.0     0.0
# (Renewed) Boya BYM1 Omnidirectional Lavalier Co...     0.0     0.0     0.0
# (Renewed) Infinity (JBL) Fuze 100 4.5 Watt Wire...     1.0     0.0     0.0
# (Renewed) Infinity Glide N100 Bluetooth Wireles...     0.0     0.0     0.0
#
# user                                                user86  user87  user88  \
# name
# "INTERN SOPRANO 21" UKULELE WITH BAG (BLACK)           0.0     0.0     0.0
# "TGC" Kaee Colour Dotted Matt Metal Bangle / Da...     0.0     0.0     0.0
# (Renewed) Boya BYM1 Omnidirectional Lavalier Co...     0.0     0.0     0.0
# (Renewed) Infinity (JBL) Fuze 100 4.5 Watt Wire...     0.0     0.0     0.0
# (Renewed) Infinity Glide N100 Bluetooth Wireles...     0.0     0.0     0.0
#
# user                                                user89  user9  user90
# name
# "INTERN SOPRANO 21" UKULELE WITH BAG (BLACK)           0.0    0.0     0.0
# "TGC" Kaee Colour Dotted Matt Metal Bangle / Da...     0.0    0.0     0.0
# (Renewed) Boya BYM1 Omnidirectional Lavalier Co...     0.0    0.0     0.0
# (Renewed) Infinity (JBL) Fuze 100 4.5 Watt Wire...     0.0    0.0     0.0
# (Renewed) Infinity Glide N100 Bluetooth Wireles...     0.0    0.0     0.0
#
# [5 rows x 91 columns]

# %%
X.shape
# Out:
# (7029, 91)

# %%
X1 = X

# %%
#Decomposing the Matrix
from sklearn.decomposition import TruncatedSVD
SVD = TruncatedSVD(n_components=10)
decomposed_matrix = SVD.fit_transform(X)
decomposed_matrix.shape
# Out:
# (7029, 10)

# %%
#Correlation Matrix

correlation_matrix = np.corrcoef(decomposed_matrix)
correlation_matrix.shape
# Out:
# (7029, 7029)

# %%
X.index[75]
# Out:
# 'ABB INITIO Adjustable Slim Shape Weight Loss Ball Pencil Speed Skipping Rope Grey (275cm)'

# %%
i = "ABB INITIO Adjustable Slim Shape Weight Loss Ball Pencil Speed Skipping Rope Grey (275cm)"

product_names = list(X.index)
product_ID = product_names.index(i)
product_ID
# Out:
# 75

# %%
correlation_product_ID = correlation_matrix[product_ID]
correlation_product_ID.shape
# Out:
# (7029,)

# %%
Recommend = list(X.index[correlation_product_ID > 0.65])

# Removes the item already bought by the customer
Recommend.remove(i) 

Recommend[0:24]
# Out:
# ['11 Pack Resistance Bands Set,Portable Exercise Resistance Band Set (5 Stackable Exercise Bands with Door Anchor, Ankle Str...',
#  '2022 Carlinkit 4.0 with Apple CarPlay dongle for Wireless Android Auto/Wireless CarPlay, 2 in 1 Fit for The OEM Factory Ca...',
#  '3M Post-it Pastel Collection Cube (5 Colors) 7.5×7.5cm CP-33SE',
#  '4 Pack Silicone Collapsible Funnel, Foldable Kitchen Funnels Hopper for Water Bottle Liquid Powder Transfer',
#  'A L N® Sweat Waist Trimmer Yoga Wrap Weight Loss Fat Burner Slimming Belt for Men and Women (Black) (Free Size)',
#  "AADI Men's Canvas Outdoor Casual Loafer - MRJ1641",
#  "ADBUCKS Women's Cotton Hooded Hoodie",
#  "ADILEE Men's Sweatpants with Zipper Pockets Tapered Track Athletic Pants for Men Running, Exercise, Workout",
#  "ADRO Men's Cotton Hooded Sweatshirt",
#  'AFPIN Adjustable Hand Gripper Wrist Exerciser Forearm Hand Grip for Gym Stretching Hand strengtheners for Men Women (Multi...',
#  'AGARO Regal Electric Rice Cooker, 3 Liters Ceramic Inner Bowl, Cooks Up to 600 Gms Raw Rice, SS Steamer, Preset Cooking Fu...',
#  'AKA CHIC Slim Women Jeans',
#  'ALIVE Womens Girls Cotton Blend Non-Padded Non-Wired Sports Bra',
#  'ALN Sweat Slim Belt Free Size Fat Burning Sauna Hot Neoprene Material Shaper Waist Trimmer Weight Loss, Lower Back Posture...',
#  'AO Smith HeatBot-SZS-025 - SILVER Storage 25 Litre Vertical Water Heater (Geyser) Silver - 4 Star',
#  'APC Easy UPS BVX1200LI-IN 1200VA / 650W, 230V, UPS System, an Ideal Power Backup & Protection for Home Office, Desktop PC...',
#  'APG Neoprene and Lycra Gym Gloves Unisex Weightlifting Gloves for Gym Workout, Crossfit, Fitness & Cross Training, Free Si...',
#  'APRODO 4’’ Inch Wide Genuine Leather Weightlifting Belt Back Support Power Training Belt Workout Exercise Power-Lifting Sq...',
#  'APRODO Leather Palm Gym Gloves with Wrist Support + Double Stitched',
#  'APRODO Professional Back Support DIP Belt with Steel Chain 36 INCHES Weighted Chain for DIPS Pull UPS Weight Lifting Cross...',
#  'ARTIBETTER Underarm Sweat Vest Underarm Sweat Guard Washable Sweat Shield Vest for Women Girls Ladies',
#  'ASICS Mens Torrance B Sneaker',
#  'ASICS Tiger Runner Blue Mens Shoes',
#  "ASICS Women's Gel-Quantum Lyte Sneakers"]

# %%
import pandas as pd
import numpy as np
from sklearn.decomposition import TruncatedSVD

import joblib # Import joblib for saving the model

def recommend_products(csv_path, target_product_id, n_reviews=10000, n_components=10, correlation_threshold=0.65, save_model_path=None):
    """
    Reads review data, performs SVD, saves the model (optional), and recommends products based on correlation.

    Args:
        csv_path (str): The path to the CSV file containing reviews.
        target_product_id (str): The ProductId for which to generate recommendations.
        n_reviews (int): The number of reviews to use from the dataset.
        n_components (int): The number of components for TruncatedSVD.
        correlation_threshold (float): The minimum correlation coefficient for a product to be recommended.
        save_model_path (str, optional): Path to save the fitted SVD model. Defaults to None (model not saved).

    Returns:
        list: A list of recommended ProductIds.
        None: If the target_product_id is not found in the processed data or an error occurs.
    """
    # Load data
    try:
        df = pd.read_csv(csv_path)
    except FileNotFoundError:
        print(f"Error: File not found at {csv_path}")
        return None
    except Exception as e:
        print(f"Error reading CSV file: {e}")
        return None


    # Select a subset of data
    new_df1 = df.head(n_reviews)

    # Create user-item matrix
    try:
        ratings_matrix = new_df1.pivot_table(values='Score', index='UserId', columns='ProductId', fill_value=0)
    except Exception as e:
        print(f"Error creating pivot table: {e}")
        return None

    # Transpose the matrix for item-based analysis
    X = ratings_matrix.T

    # Check if the target product exists after filtering and pivoting
    if target_product_id not in X.index:
        print(f"Error: ProductId '{target_product_id}' not found in the first {n_reviews} reviews.")
        # You might want to suggest trying a larger n_reviews or checking the ID
        # Or return available product IDs: print("Available Product IDs in this subset:", list(X.index))
        return None

    # Decompose the matrix using SVD
    try:
        SVD_model = TruncatedSVD(n_components=n_components, random_state=42) # Added random_state for reproducibility
        decomposed_matrix = SVD_model.fit_transform(X)
    except Exception as e:
        print(f"Error during SVD fitting: {e}")
        return None


    # Save the fitted SVD model if a path is provided
    if save_model_path:
        try:
            joblib.dump(SVD_model, save_model_path)
            print(f"SVD model saved to {save_model_path}")
        except Exception as e:
            print(f"Error saving SVD model to {save_model_path}: {e}")
            # Continue with recommendations even if saving fails, but notify the user.

    # Calculate the correlation matrix
    try:
        correlation_matrix = np.corrcoef(decomposed_matrix)
    except Exception as e:
        print(f"Error calculating correlation matrix: {e}")
        return None


    # Find the index of the target product
    product_names = list(X.index)
    try:
        product_ID_index = product_names.index(target_product_id)
    except ValueError:
         # This case should ideally be caught earlier, but added as a safeguard
        print(f"Error: ProductId '{target_product_id}' index not found after SVD (this shouldn't happen if checked before).")
        return None


    # Get the correlation vector for the target product
    correlation_product_ID = correlation_matrix[product_ID_index]

    # Generate recommendations
    try:
        recommend_indices = np.where(correlation_product_ID > correlation_threshold)[0] # Get indices directly
        Recommend = [product_names[idx] for idx in recommend_indices if idx != product_ID_index] # Build list and exclude target
    except Exception as e:
        print(f"Error generating recommendations from correlations: {e}")
        return None

    # Return the top recommendations (optional: limit the number)
    return Recommend[:24] # Keep the limit as in the original notebook

# Example usage:
csv_file = '/home/madhu/recommendation-systems/data/Reviews.csv'
product_to_recommend_for = "B0004MZVIA"
model_save_file = '/home/madhu/recommendation-systems/models/svd.joblib' # Define path to save the model

# Call the function, providing the path to save the model
recommendations = recommend_products(csv_file, product_to_recommend_for, save_model_path=model_save_file)

if recommendations is not None:
    print(f"\nRecommendations for {product_to_recommend_for}:")
    if recommendations:
        print(recommendations)
    else:
        print("No products found above the correlation threshold.")
# Out:
# SVD model saved to /home/madhu/recommendation-systems/models/svd.joblib
#
# Recommendations for B0004MZVIA:
# ['B000084EK4', 'B000084EK5', 'B000084EK6', 'B000084EK7', 'B000084EK8', 'B000084EK9', 'B000084EKA', 'B000084EKB', 'B000084EKC', 'B000084EKD', 'B000084EKG', 'B000084EKO', 'B000084EKW', 'B0000E65W9', 'B0000TU8EO', 'B0002567IW', 'B00029XIZI', 'B00032B7AM', 'B0004MUZKO', 'B0005Z6EUU', 'B0005ZHWXI', 'B00061NJ06', 'B00067ITNW', 'B0009QWTMM']

# %%
# Optional: Example of loading the saved model later
try:
    loaded_svd_model = joblib.load(model_save_file)
    print(f"\nSuccessfully loaded SVD model from {model_save_file}")
    # You could now use loaded_svd_model.transform() on new data (if applicable)
    # or use its components_ attribute, etc.
except FileNotFoundError:
    print(f"\nModel file {model_save_file} not found. Run the recommendation function first to save it.")
except Exception as e:
    print(f"\nError loading model: {e}")
# Out:
# Successfully loaded SVD model from /home/madhu/recommendation-systems/models/svd.joblib

# %%
from app.models import ProductHybridModel

hybrid_model = ProductHybridModel(csv_path='/home/madhu/recommendation-systems/data/user_ratings.csv',save_model_dir='/home/madhu/recommendation-systems/models/')
# Out:
# Data loaded successfully from /home/madhu/recommendation-systems/data/user_ratings.csv
# Using the first 10000 reviews for training.
# Pivot table created successfully.
# Matrix transposed. Shape: (7029, 91)
# SVD performed with 10 components. Decomposed matrix shape: (7029, 10)
# Model data (decomposed matrix and product names) saved to /home/madhu/recommendation-systems/models/svd_model_user_data.joblib
# Correlation matrix calculated and stored.

# %%
hybrid_model.recommend_products(target_product_id="ABB INITIO Adjustable Slim Shape Weight Loss Ball Pencil Speed Skipping Rope Grey (275cm)")
# Out:
# Found 428 recommendations for 'ABB INITIO Adjustable Slim Shape Weight Loss Ball Pencil Speed Skipping Rope Grey (275cm)' with threshold 0.65.
# ['2022 Carlinkit 4.0 with Apple CarPlay dongle for Wireless Android Auto/Wireless CarPlay, 2 in 1 Fit for The OEM Factory Ca...',
#  '4 Pack Silicone Collapsible Funnel, Foldable Kitchen Funnels Hopper for Water Bottle Liquid Powder Transfer',
#  "7 season's Cotton Long Scarf Cum Mask Universal Size/Usable for vehicle Driver for sunlight UV protection/White Printed De...",
#  'A L N® Sweat Waist Trimmer Yoga Wrap Weight Loss Fat Burner Slimming Belt for Men and Women (Black) (Free Size)',
#  "AADI Men's Canvas Outdoor Casual Loafer - MRJ1641",
#  "ADBUCKS Women's Cotton Hooded Hoodie",
#  "ADILEE Men's Sweatpants with Zipper Pockets Tapered Track Athletic Pants for Men Running, Exercise, Workout",
#  "ADRO Men's Cotton Hooded Sweatshirt",
#  'AFPIN Adjustable Hand Gripper Wrist Exerciser Forearm Hand Grip for Gym Stretching Hand strengtheners for Men Women (Multi...',
#  'AGARO Regal Electric Rice Cooker, 3 Liters Ceramic Inner Bowl, Cooks Up to 600 Gms Raw Rice, SS Steamer, Preset Cooking Fu...',
#  "AIZAH Women's Sling Bag",
#  'AKA CHIC Women Women Jeans',
#  'ALIVE Womens Girls Cotton Blend Non-Padded Non-Wired Sports Bra',
#  'AO Smith HeatBot-SZS-025 - SILVER Storage 25 Litre Vertical Water Heater (Geyser) Silver - 4 Star',
#  'APG Neoprene and Lycra Gym Gloves Unisex Weightlifting Gloves for Gym Workout, Crossfit, Fitness & Cross Training, Free Si...',
#  'ARMODA Women Shoulder Bag',
#  "ASIAN Men's Sandal",
#  "ASICS Women's Gel-Quantum Lyte Sneakers",
#  'AUMEY Large Flat Chain Strap - Acrylic Chain Luxury Handbag Strap Fashionable Replacement Purse Clutches Handles for Purse...',
#  'AUXTER Music 33 Ltrs Black School Bag Travel Bagpack Casual Backpack',
#  "Aashish Fabrics Women's Plus Size Cotton Lycra Churidar Leggings (Pack of 2)",
#  "Abhi Women's Cotton Sleeveless Blouse",
#  'Action Pro 360° Rotation Pocket Backpack Mount Compatible with DJI OSMO Pocket',
#  'Action Pro Small Carrying Case Protective Bag with Water Resistant EVA Compatible with GoPro Hero 11 10 9 8 7 6 5 4 3+ 3 S...']

# %%
import boto3
import joblib
from io import BytesIO

# Define S3 path
# IMPORTANT: Replace 'your-s3-bucket-name' with your actual S3 bucket name
s3_bucket = 'your-s3-bucket-name'
s3_key = 'models/svd.joblib' # Path within the bucket where the model will be saved
s3_path = f"s3://{s3_bucket}/{s3_key}"

try:
    # Check if the model object exists (it should have been loaded in cell 13)
    if 'loaded_svd_model' in locals():
        print(f"Found model object 'loaded_svd_model' of type: {type(loaded_svd_model)}")

        # Serialize the model to an in-memory buffer using joblib
        buffer = BytesIO()
        joblib.dump(loaded_svd_model, buffer)
        buffer.seek(0) # Reset buffer position to the beginning before reading

        # Initialize S3 client
        s3_client = boto3.client('s3')

        # Upload the buffer content to S3
        s3_client.put_object(Bucket=s3_bucket, Key=s3_key, Body=buffer.getvalue())

        print(f"Successfully uploaded model to {s3_path}")

    else:
        # This error occurs if cell 13, which defines loaded_svd_model, hasn't been run or failed
        print("Error: The variable 'loaded_svd_model' was not found.")
        print("Please ensure the cell that loads the model (cell 13) has been executed successfully before running this cell.")

except ImportError:
    print("Error: boto3 or joblib library not found. Please install them (e.g., pip install boto3 joblib)")
except Exception as e:
    # Catch potential exceptions during S3 interaction (e.g., credentials, permissions, network)
    print(f"An error occurred during the S3 upload process: {e}")
