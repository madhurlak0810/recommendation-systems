# %%
import pandas as pd
import glob

# %%
files = glob.glob("data/*.csv")
df = pd.concat(map(pd.read_csv, files), ignore_index=True)
df
# Out:
#                                                       name    main_category  \
# 0        Skybags Treble-FIFA 68cm Printed Polycarbonate...   bags & luggage
# 1        Tommy Hilfiger Plastic Hard 66 cms Luggage (89...   bags & luggage
# 2        Samsonite Polyester Hard 68 Cms Luggage- Suitc...   bags & luggage
# 3        Skybags Polycarbonate Hard 21 Cms Suitcase(_Blue)   bags & luggage
# 4        Skybags Game-ON FIFA 79cm Printed Polycarbonat...   bags & luggage
# ...                                                    ...              ...
# 1103165  Zimmer Aufraumen Tap, Faucet Sink & Shower Cle...  beauty & health
# 1103166  SHREE HANS FASHION | Stainless Steel Straws wi...  beauty & health
# 1103167  Mridaya Biotic Pure and Organic Citric Acid Cr...  beauty & health
# 1103168  Mush Ultra Soft & Super Absorbent Bamboo Hoode...  beauty & health
# 1103169  Dwarakesh Enterprises® 4V 1500mAh (1.5Ah) Main...  beauty & health
#
#                      sub_category  \
# ...
